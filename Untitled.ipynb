# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
os.getcwd()
os.chdir('../..')
os.getcwd()
# Out:
# '/home/dcmorgan'

# %%
depth=pd.read_csv('assemble/GMOREA0050-DNA/depth.txt',sep='\t',header=None)
# hits=pd.read_csv('assemble/GMOREA0109-DNA/viral_hits.blast',sep='\t',names=['name','tmp','identity','tmp1','tmp2','tmp3','tmp4','tmp5','tmp8','tmp12','tmp13','tmp11'])
# hits=hits[['name','identity']]

# %%
depth.groupby([0]).sum()
# Out:
#                    1    2
# 0
# k141_34085    351531  302
# k141_44674    549338  232
# k141_85434  59100947  302
# k141_90646     13741  151
# k141_91057   1370476  167

# %%
import seaborn as sns, numpy as np, pandas as pd
from numpy import inf

data=pd.read_csv('assemble/contig_counts.tsv',sep='\t')
data=data.drop(columns='length').melt(['contig']).replace({'-DNA.idxstats.txt':' '}, regex=True)

plt.figure(figsize=(8,12))
data['log_value']=np.log10(data.value)
data['log_value'][np.isneginf(data['log_value'])] = 0
data['log_abundance']=data['log_value'].fillna(0)
tmp=sns.violinplot(data=data, y="variable", x="log_abundance",scale="count")
# Out:
# /home/dcmorgan/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:405: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /tmp/ipykernel_19559/604365329.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['log_value'][np.isneginf(data['log_value'])] = 0

# %%
plt.figure(figsize=(8,12))
tmp=sns.boxplot(data=data, y="variable", x="log_abundance")
